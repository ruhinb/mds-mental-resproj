# %% [markdown]
# LOAD DATA

# %%
import pandas as pd
import numpy as np
import torch
from google.colab import drive

drive.mount('/content/drive')

df_flat = pd.read_csv("/content/beyondblue_data_flattened.csv")
df_flat['text'] = df_flat['text'].astype(str).fillna("")
df_flat.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    parent_post_id          user_id       role  \
# 0               1             Toby   original
# 1               1            Morph  commenter
# 2               1  AudaciousPoodle  commenter
# 3               1           _Gigi_  commenter
# 4               1             Toby   op_reply
#
#                                                 text        date category
# 0  Struggling at the moment. Hello everyone, this...  2025-07-16  Anxiety
# 1  Hi Toby, welcome and congratulations on your f...  2025-07-17  Anxiety
# 2  Hi Toby, Reading your post sounds just like wh...  2025-07-17  Anxiety
# 3  Hello Toby,I'm glad you've decided to reach ou...  2025-07-18  Anxiety
# 4  My anxiety is affecting my whole life. When I ...  2025-07-18  Anxiety

# %% [markdown]
# DEVICE SETUP

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %% [markdown]
# LOAD TRANSFORMER MODELS

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from torch.nn.functional import softmax

# %% [markdown]
# Twitter RoBERTa SENTIMENT MODEL (3-way)

# %%
sentiment_model_name = "cardiffnlp/twitter-roberta-base-sentiment-latest"

sent_tok = AutoTokenizer.from_pretrained(sentiment_model_name, use_fast=True)
sent_model = AutoModelForSequenceClassification.from_pretrained(
    sentiment_model_name
).to(device)

# Label order for this model:
sent_labels = ["NEGATIVE", "NEUTRAL", "POSITIVE"]
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# DistilRoBERTa EMOTION MODEL

# %%
emotion_model_name = "j-hartmann/emotion-english-distilroberta-base"

emo_tok = AutoTokenizer.from_pretrained(emotion_model_name, use_fast=True)
emo_model = AutoModelForSequenceClassification.from_pretrained(
    emotion_model_name
).to(device)

emo_labels = ["anger", "disgust", "fear", "joy", "neutral", "sadness", "surprise"]

# %% [markdown]
# BATCH INFERENCE FUNCTION

# %%
def predict_dist(texts, tokenizer, model, labels, batch_size=16, max_length=512):
    all_probs = []
    model.eval()
    with torch.no_grad():
        for i in range(0, len(texts), batch_size):
            batch = texts[i:i+batch_size]
            enc = tokenizer(
                batch,
                padding=True,
                truncation=True,
                max_length=max_length,
                return_tensors="pt"
            ).to(device)
            logits = model(**enc).logits
            probs = softmax(logits, dim=-1).cpu().numpy()

            for p in probs:
                all_probs.append({lab: float(p[j]) for j, lab in enumerate(labels)})
    return all_probs

# %% [markdown]
# RUN BOTH MODELS

# %%
texts = df_flat["text"].tolist()

print("Running Twitter RoBERTa sentiment...")
sent_dists = predict_dist(texts, sent_tok, sent_model, sent_labels, batch_size=16)

print("Running DistilRoBERTa emotion...")
emo_dists = predict_dist(texts, emo_tok, emo_model, emo_labels, batch_size=16)
# Out:
# Running Twitter RoBERTa sentiment...
# Running DistilRoBERTa emotion...

# %% [markdown]
# SENTIMENT → CONTINUOUS VALENCE

# %%
def valence_from_sentiment(dist):
    pos = dist.get("POSITIVE", 0.0)
    neg = dist.get("NEGATIVE", 0.0)
    return float(pos - neg)   # in [-1,1] roughly

# %% [markdown]
# EMOTION → Valence/Arousal using NRC-VAD

# %%
emo_to_va = {
    "joy":       {"val": 0.9800, "aro": 0.8240},
    "surprise":  {"val": 0.8750, "aro": 0.8750},
    "neutral":   {"val": 0.4690, "aro": 0.1840},
    "sadness":   {"val": 0.0520, "aro": 0.2880},
    "fear":      {"val": 0.0730, "aro": 0.8400},
    "anger":     {"val": 0.1670, "aro": 0.8650},
    "disgust":   {"val": 0.0520, "aro": 0.7750},
}

def va_from_emotion_dist(dist):
    if not dist:
        return 0.0, 0.5

    v = a = tot = 0.0
    for emo, p in dist.items():
        m = emo_to_va.get(emo.lower())
        if m:
            v += m["val"] * p
            a += m["aro"] * p
            tot += p

    if tot > 0:
        v /= tot
        a /= tot

    return float(v), float(a)

# %% [markdown]
# ADD EVERYTHING BACK TO DATAFRAME

# %%
df_flat["sentiment_dist"] = sent_dists
df_flat["valence_s"] = [valence_from_sentiment(d) for d in sent_dists]
df_flat["sentiment_top"] = [max(d, key=d.get) if d else None for d in sent_dists]
df_flat["sentiment_conf"] = [max(d.values()) if d else None for d in sent_dists]

df_flat["emotion_dist"] = emo_dists
va = [va_from_emotion_dist(d) for d in emo_dists]
df_flat["valence_e"], df_flat["arousal_e"] = zip(*va)
df_flat["emotion_top"] = [max(d, key=d.get) if d else None for d in emo_dists]
df_flat["emotion_conf"] = [max(d.values()) if d else None for d in emo_dists]

# %% [markdown]
# SAVE

# %%
output_path = "/content/beyondblue_data_flattened_transformers_enriched_.csv"
df_flat.to_csv(output_path, index=False)

print("Saved enriched dataset →", output_path)
# Out:
# Saved enriched dataset → /content/beyondblue_data_flattened_transformers_enriched_.csv

# %%
df_test = pd.read_csv("/content/beyondblue_data_flattened_transformers_enriched_.csv")
df_test.head()
# Out:
#    parent_post_id          user_id       role  \
# 0               1             Toby   original
# 1               1            Morph  commenter
# 2               1  AudaciousPoodle  commenter
# 3               1           _Gigi_  commenter
# 4               1             Toby   op_reply
#
#                                                 text        date category  \
# 0  Struggling at the moment. Hello everyone, this...  2025-07-16  Anxiety
# 1  Hi Toby, welcome and congratulations on your f...  2025-07-17  Anxiety
# 2  Hi Toby, Reading your post sounds just like wh...  2025-07-17  Anxiety
# 3  Hello Toby,I'm glad you've decided to reach ou...  2025-07-18  Anxiety
# 4  My anxiety is affecting my whole life. When I ...  2025-07-18  Anxiety
#
#                                       sentiment_dist  valence_s sentiment_top  \
# 0  {'NEGATIVE': 0.6358404159545898, 'NEUTRAL': 0....  -0.573182      NEGATIVE
# 1  {'NEGATIVE': 0.0026518572121858597, 'NEUTRAL':...   0.971309      POSITIVE
# 2  {'NEGATIVE': 0.7963149547576904, 'NEUTRAL': 0....  -0.754034      NEGATIVE
# 3  {'NEGATIVE': 0.01175833772867918, 'NEUTRAL': 0...   0.903619      POSITIVE
# 4  {'NEGATIVE': 0.6501988172531128, 'NEUTRAL': 0....  -0.580363      NEGATIVE
#
#    sentiment_conf                                       emotion_dist  \
# 0        0.635840  {'anger': 0.0006829296471551061, 'disgust': 0....
# 1        0.973961  {'anger': 0.0020849828142672777, 'disgust': 0....
# 2        0.796315  {'anger': 0.0018220562487840652, 'disgust': 0....
# 3        0.915377  {'anger': 0.0011325412197038531, 'disgust': 0....
# 4        0.650199  {'anger': 0.005803769454360008, 'disgust': 0.0...
#
#    valence_e  arousal_e emotion_top  emotion_conf
# 0   0.074732   0.838692        fear      0.995240
# 1   0.897350   0.742547         joy      0.817238
# 2   0.058975   0.301366     sadness      0.969912
# 3   0.925508   0.790216         joy      0.927660
# 4   0.179508   0.471812     sadness      0.592458

# %%
import pandas as pd

# If not already loaded, load your flattened data
df_flat = pd.read_csv("/content/beyondblue_data_flattened.csv")
df_flat['text'] = df_flat['text'].astype(str).fillna("")

# Sample 50 posts for manual labeling (change 50 if you want)
val_sample = df_flat.sample(50, random_state=42)[['text']].copy()

# Add empty columns for your labels
val_sample['valence_human'] = ""   # negative / neutral / positive
val_sample['emotion_human'] = ""   # anger / disgust / fear / joy / neutral / sadness / surprise

val_path = "/content/validation_sample_for_labeling.csv"
val_sample.to_csv(val_path, index=False)

val_path
# Out:
# '/content/validation_sample_for_labeling.csv'

# %%
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from torch.nn.functional import softmax

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# Load your labeled validation set
val_df = pd.read_csv("/content/validation_sample_labeled.csv")

val_df['text'] = val_df['text'].astype(str)

# Make sure labels are lowercase and stripped
val_df['valence_human'] = val_df['valence_human'].str.strip().str.lower()
val_df['emotion_human'] = val_df['emotion_human'].str.strip().str.lower()
# Out:
# Using device: cuda

# %%
# Twitter RoBERTa sentiment
sentiment_model_name = "cardiffnlp/twitter-roberta-base-sentiment-latest"
sent_tok = AutoTokenizer.from_pretrained(sentiment_model_name, use_fast=True)
sent_model = AutoModelForSequenceClassification.from_pretrained(
    sentiment_model_name
).to(device)
sent_labels = ["NEGATIVE", "NEUTRAL", "POSITIVE"]

# DistilRoBERTa emotion
emotion_model_name = "j-hartmann/emotion-english-distilroberta-base"
emo_tok = AutoTokenizer.from_pretrained(emotion_model_name, use_fast=True)
emo_model = AutoModelForSequenceClassification.from_pretrained(
    emotion_model_name
).to(device)
emo_labels = ["anger","disgust","fear","joy","neutral","sadness","surprise"]
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def predict_sentiment_label(text):
    enc = sent_tok(
        text,
        return_tensors="pt",
        truncation=True,
        padding=True,
        max_length=256
    ).to(device)
    with torch.no_grad():
        logits = sent_model(**enc).logits
        probs = softmax(logits, dim=-1)[0].cpu().numpy()
    idx = probs.argmax()
    return sent_labels[idx].lower()   # -> "negative"/"neutral"/"positive"


def predict_emotion_label(text):
    enc = emo_tok(
        text,
        return_tensors="pt",
        truncation=True,
        padding=True,
        max_length=256
    ).to(device)
    with torch.no_grad():
        logits = emo_model(**enc).logits
        probs = softmax(logits, dim=-1)[0].cpu().numpy()
    idx = probs.argmax()
    return emo_labels[idx].lower()

# %%
val_df['valence_model'] = val_df['text'].apply(predict_sentiment_label)
val_df['emotion_model'] = val_df['text'].apply(predict_emotion_label)

val_df[['text','valence_human','valence_model','emotion_human','emotion_model']].head(50)
# Out:
#                                                  text valence_human  \
# 0   PTSD,Fear and abdominal problems. Hi  i am a 8...      negative
# 1   Hello Dear soonie1, A very warm welcome to our...      positive
# 2   New job opportunity anxiety. I work at a schoo...      negative
# 3   My brother grew up with milk allergies, but .....      negative
# 4   Hi, I totally get how you feel. I'm about ti m...       neutral
# 5   Physical symptoms anxiety. I have recently gon...      negative
# 6   Hi mchops, I am in a similar boat to you excep...      negative
# 7   Hi Atleigh. I think it's brave that you tried ...       neutral
# 8   Dear anna630,If you can identify that you are ...      negative
# 9   Thank you Thorney, I do journal. I didn’t like...      positive
# 10  Hello and welcome to the forums. Really sorry ...      positive
# 11  Hi Angelo213 What you're facing sounds so upse...      negative
# 12  Dear Anxiety,You always know when to drop in. ...       neutral
# 13  Eco anxiety in Perth. Hi, we are in the middle...      negative
# 14  Hi. I like your post. It’s wonderful you have ...      negative
# 15  I often have this especially when i have a pan...       neutral
# 16  Thank you therising for giving some insight in...       neutral
# 17  Hmmm hey bigaloohope you are doing better toda...      positive
# 18  OCD and intrusive/aggressive/taboo thoughts - ...      negative
# 19  Hi Whatsinaname, Yes, get out if you can! It's...      positive
# 20  Feeling Broken. First time here and first time...      negative
# 21  Hi Guest Warm welcome to the forum and I'm so ...      positive
# 22  ALWAYS HERE. No matter how low you are feeling...      positive
# 23  Hi Chris, welcome I can identify with your exp...       neutral
# 24  Yeah I’ve been here before and I know it passe...      negative
# 25  Thank you for your reply. I’m sure of my decis...      positive
# 26  Anxiety or Depression?. Greetings to everyone ...       neutral
# 27  working makes me want to throw up. this is my ...      negative
# 28  Hi and thanks for your kind reply.      Im sor...      positive
# 29  Thanks Geoff and Billie,  My psychologist aske...      negative
# 30  My story and no help. And hated for it,. This ...      negative
# 31  Hi Whatsinaname, I hope you don't mind me jump...       neutral
# 32  Hi ,I found it interesting about talking to yo...      positive
# 33  Hi Guest_68394701 Sorry to hear you have been ...       neutral
# 34  Thanks for that. I have spent a few years revi...      negative
# 35  Hi, welcome Your symptoms are quite serious. W...       neutral
# 36  In was completely terrified about my test I th...      positive
# 37  Hello SH, I'm so sorry to hear that you're hav...       neutral
# 38  Dear smallwolf, Rest well and really glad you ...      positive
# 39  How do I get through school as a teen with ADH...      negative
# 40  Thank you, I will read through the links that ...      positive
# 41  Hey AlyciaYou are strong by speaking from the ...      positive
# 42  Hello and thank you for sharing your story and...       neutral
# 43  Anxiety. Hi I am a 64 year old male married fo...      negative
# 44  Anxiety & Depression. I am a 50 year old, who ...      negative
# 45  Sam, thank you for reaching out to us, and wel...      positive
# 46  Upset. Just for context I have lived in the sa...      negative
# 47  Anxiety and not able to eat in public. I am an...      negative
# 48        Yep.  Went to jail for this @@@#ing illness      negative
# 49  Dear _kj,Personally, and not offensively, it s...      positive
#
#    valence_model emotion_human emotion_model
# 0       negative          fear          fear
# 1       negative           joy       sadness
# 2       negative          fear          fear
# 3       negative         anger       sadness
# 4        neutral           joy       neutral
# 5       negative          fear          fear
# 6       negative       sadness          fear
# 7        neutral       neutral       neutral
# 8        neutral          fear          fear
# 9        neutral           joy          fear
# 10      negative       neutral          fear
# 11      negative          fear          fear
# 12      negative          fear          fear
# 13      negative          fear          fear
# 14      negative       disgust       disgust
# 15       neutral          fear          fear
# 16       neutral       neutral       sadness
# 17      negative           joy       sadness
# 18       neutral          fear          fear
# 19      positive           joy           joy
# 20      negative       sadness       sadness
# 21       neutral           joy          fear
# 22      positive           joy       neutral
# 23       neutral       sadness       neutral
# 24      negative       neutral       neutral
# 25      positive           joy           joy
# 26       neutral       sadness       sadness
# 27      negative          fear          fear
# 28      positive           joy           joy
# 29       neutral          fear          fear
# 30      negative       disgust       sadness
# 31       neutral       sadness       sadness
# 32      positive       neutral          fear
# 33       neutral       sadness       sadness
# 34      negative          fear          fear
# 35       neutral          fear          fear
# 36      negative           joy          fear
# 37      negative       sadness       sadness
# 38      positive           joy           joy
# 39      negative      surprise          fear
# 40      positive           joy          fear
# 41      positive           joy          fear
# 42       neutral          fear          fear
# 43      negative       sadness          fear
# 44      negative       sadness         anger
# 45      positive       neutral          fear
# 46      negative          fear      surprise
# 47      negative          fear          fear
# 48      negative         anger       sadness
# 49      negative           joy       neutral

# %%
# %pip install scikit-learn --quiet

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# ---- Sentiment (valence) ----
sent_acc = accuracy_score(val_df['valence_human'], val_df['valence_model'])
print("Sentiment agreement (human vs model):", sent_acc)

print("\nSentiment confusion matrix:\n")
print(confusion_matrix(val_df['valence_human'], val_df['valence_model'], labels=["negative","neutral","positive"]))

print("\nSentiment classification report:\n")
print(classification_report(val_df['valence_human'], val_df['valence_model'], labels=["negative","neutral","positive"]))


# ---- Emotion ----
emo_acc = accuracy_score(val_df['emotion_human'], val_df['emotion_model'])
print("Emotion agreement (human vs model):", emo_acc)

print("\nEmotion confusion matrix:\n")
print(confusion_matrix(val_df['emotion_human'], val_df['emotion_model'], labels=emo_labels))

print("\nEmotion classification report:\n")
print(classification_report(val_df['emotion_human'], val_df['emotion_model'], labels=emo_labels))
# Out:
# Sentiment agreement (human vs model): 0.76
#
# Sentiment confusion matrix:
#
# [[19  3  0]
#  [ 2 10  0]
#  [ 5  2  9]]
#
# Sentiment classification report:
#
#               precision    recall  f1-score   support
#
#     negative       0.73      0.86      0.79        22
#      neutral       0.67      0.83      0.74        12
#     positive       1.00      0.56      0.72        16
#
#     accuracy                           0.76        50
#    macro avg       0.80      0.75      0.75        50
# weighted avg       0.80      0.76      0.76        50
#
# Emotion agreement (human vs model): 0.54
#
# Emotion confusion matrix:
#
# [[ 0  0  0  0  0  2  0]
#  [ 0  1  0  0  0  1  0]
#  [ 0  0 15  0  0  0  1]
#  [ 0  0  5  4  3  2  0]
#  [ 0  0  3  0  2  1  0]
#  [ 1  0  2  0  1  5  0]
#  [ 0  0  1  0  0  0  0]]
#
# Emotion classification report:
#
#               precision    recall  f1-score   support
#
#        anger       0.00      0.00      0.00         2
#      disgust       1.00      0.50      0.67         2
#         fear       0.58      0.94      0.71        16
#          joy       1.00      0.29      0.44        14
#      neutral       0.33      0.33      0.33         6
#      sadness       0.45      0.56      0.50         9
#     surprise       0.00      0.00      0.00         1
#
#     accuracy                           0.54        50
#    macro avg       0.48      0.37      0.38        50
# weighted avg       0.63      0.54      0.51        50

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Sentiment (valence) Confusion Matrix
sent_cm = confusion_matrix(val_df['valence_human'], val_df['valence_model'], labels=["negative","neutral","positive"])
plt.figure(figsize=(8, 6))
sns.heatmap(sent_cm, annot=True, fmt="d", cmap="Blues", xticklabels=["negative","neutral","positive"], yticklabels=["negative","neutral","positive"])
plt.title(f'Sentiment Confusion Matrix (Accuracy: {sent_acc:.2f})')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Emotion Confusion Matrix
emo_cm = confusion_matrix(val_df['emotion_human'], val_df['emotion_model'], labels=emo_labels)
plt.figure(figsize=(10, 8))
sns.heatmap(emo_cm, annot=True, fmt="d", cmap="Greens", xticklabels=emo_labels, yticklabels=emo_labels)
plt.title(f'Emotion Confusion Matrix (Accuracy: {emo_acc:.2f})')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
# Cases where sentiment disagrees
val_df[val_df['valence_human'] != val_df['valence_model']][
    ['text','valence_human','valence_model']
].head(10)

# Cases where emotion disagrees
val_df[val_df['emotion_human'] != val_df['emotion_model']][
    ['text','emotion_human','emotion_model']
].head(10)
# Out:
#                                                  text emotion_human  \
# 1   Hello Dear soonie1, A very warm welcome to our...           joy
# 3   My brother grew up with milk allergies, but .....         anger
# 4   Hi, I totally get how you feel. I'm about ti m...           joy
# 6   Hi mchops, I am in a similar boat to you excep...       sadness
# 9   Thank you Thorney, I do journal. I didn’t like...           joy
# 10  Hello and welcome to the forums. Really sorry ...       neutral
# 16  Thank you therising for giving some insight in...       neutral
# 17  Hmmm hey bigaloohope you are doing better toda...           joy
# 21  Hi Guest Warm welcome to the forum and I'm so ...           joy
# 22  ALWAYS HERE. No matter how low you are feeling...           joy
#
#    emotion_model
# 1        sadness
# 3        sadness
# 4        neutral
# 6           fear
# 9           fear
# 10          fear
# 16       sadness
# 17       sadness
# 21          fear
# 22       neutral
